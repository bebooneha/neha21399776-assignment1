# %% [markdown]
# <a href="https://colab.research.google.com/github/bebooneha/neha21399776-assignment1/blob/main/assessment_1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
with open("utility.csv", 'w')  as utility:
  writer = csv.writer(utility)
  writer.writerow(['month', 'electricity_usage',' Electricity_source','water_usage','Gas_usage'])

  #

  for i in range(0,12):
    #
    month = input("Enter month: ")
    electricity_usage = float(input("Enter electricity usage: "))
    Electricity_source =input("Enter Electricity source:")
    water_usage = float(input("Enter water usage:"))
    Gas_usage=float(input("Enter gas usage"))

    # write user data to file
    writer.writerow([month, electricity_usage, Electricity_source, water_usage, Gas_usage])

# %%
# with open('utility.csv', 'r') as utility:
    #csvreader = csv.reader(utility)

    #for row in csvreader:
      #  print(row) # print each row in the file
import pandas as pd
utility = pd.read_csv("utility.csv", sep=',')

# %%
utility
# Out:
#     month  electricity_usage  Electricity_source  water_usage  Gas_usage
# 0     jan              100.0                wind         90.0       80.0
# 1     feb              120.0               solar         80.0       90.0
# 2   march              110.0                wind        110.0      100.0
# 3   april              100.0                wind         70.0       80.0
# 4     may               90.0               water        100.0       80.0
# 5    june               90.0                wind         70.0       80.0
# 6    july              100.0               water         80.0       90.0
# 7     aug               90.0                wind        100.0       90.0
# 8    sept              100.0               water         90.0       80.0
# 9     oct               90.0               solar        100.0       80.0
# 10    nov              100.0                wind         90.0       80.0
# 11    dec              100.0                wind         80.0       70.0

# %%
import matplotlib.pyplot as plt
plt.plot(utility['month'],utility['electricity_usage'])
plt.xlabel('Month')
plt.ylabel('Energy consumption')
plt.title('Enrtgy consumption trend')
plt.show()

# %%
plt.bar(utility[' Electricity_source'],utility['electricity_usage'],color='blue')
plt.show()

# %%
annual_energy_consumption = utility.groupby(' Electricity_source')['electricity_usage'].sum()
annual_energy_consumption.plot(kind='bar',color='blue')

plt.show()
